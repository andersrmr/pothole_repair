# %%
import pandas as pd
import numpy as np
import cPickle as pickle
import datetime

# %%
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_pickle('df_1to10999_geo_cleaned.pkl')

# %%
df_weather = pd.read_csv('data/weather.csv')

# %%
df_weather.head(2)
# Out:
#   Conditions Dew Point Events Gust Speed Heat Index Humidity Precip  Pressure  \
# 0      Clear   55.0 °F    NaN          -        NaN      68%    NaN  29.97 in
# 1      Clear   54.0 °F    NaN          -        NaN      68%    NaN  29.96 in
#
#      Temp.      Time Visibility Wind Dir Wind Speed Windchill        date
# 0  66.0 °F  12:53 AM    10.0 mi     Calm       Calm       NaN  2015-09-13
# 1  64.9 °F   1:53 AM    10.0 mi     Calm       Calm       NaN  2015-09-13

# %%
df_weather.head()
# Out:
#       Conditions Dew Point Events Gust Speed Heat Index Humidity Precip  \
# 0          Clear   55.0 °F    NaN          -        NaN      68%    NaN
# 1          Clear   54.0 °F    NaN          -        NaN      68%    NaN
# 2  Mostly Cloudy   55.9 °F    NaN          -        NaN      75%    NaN
# 3  Mostly Cloudy   57.2 °F    NaN          -        NaN      82%    NaN
# 4       Overcast   57.0 °F    NaN          -        NaN      84%    NaN
#
#    Pressure    Temp.      Time Visibility Wind Dir Wind Speed Windchill  \
# 0  29.97 in  66.0 °F  12:53 AM    10.0 mi     Calm       Calm       NaN
# 1  29.96 in  64.9 °F   1:53 AM    10.0 mi     Calm       Calm       NaN
# 2  29.97 in  64.0 °F   2:53 AM    10.0 mi      WSW    3.5 mph       NaN
# 3  29.98 in  62.6 °F   3:37 AM    10.0 mi       SW    4.6 mph       NaN
# 4  29.98 in  62.1 °F   3:53 AM    10.0 mi    South    3.5 mph       NaN
#
#          date
# 0  2015-09-13
# 1  2015-09-13
# 2  2015-09-13
# 3  2015-09-13
# 4  2015-09-13

# %%
df_weather.head(30)
# Out:
#           Conditions Dew Point Events Gust Speed Heat Index Humidity   Precip  \
# 0              Clear   55.0 °F    NaN          -        NaN      68%      NaN
# 1              Clear   54.0 °F    NaN          -        NaN      68%      NaN
# 2      Mostly Cloudy   55.9 °F    NaN          -        NaN      75%      NaN
# 3      Mostly Cloudy   57.2 °F    NaN          -        NaN      82%      NaN
# 4           Overcast   57.0 °F    NaN          -        NaN      84%      NaN
# 5           Overcast   57.0 °F    NaN          -        NaN      84%      NaN
# 6           Overcast   57.0 °F    NaN          -        NaN      84%      NaN
# 7           Overcast   57.0 °F    NaN          -        NaN      81%      NaN
# 8           Overcast   57.0 °F    NaN          -        NaN      81%      NaN
# 9         Light Rain   57.9 °F   Rain          -        NaN      86%  0.01 in
# 10        Light Rain   57.2 °F   Rain          -        NaN      82%  0.01 in
# ...

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61551 entries, 0 to 61550
# Data columns (total 15 columns):
# Conditions    61551 non-null object
# Dew Point     61551 non-null object
# Events        8733 non-null object
# Gust Speed    61551 non-null object
# Heat Index    3397 non-null object
# Humidity      61551 non-null object
# Precip        12018 non-null object
# Pressure      61551 non-null object
# Temp.         61551 non-null object
# Time          61551 non-null object
# Visibility    61551 non-null object
# Wind Dir      61551 non-null object
# Wind Speed    61551 non-null object
# Windchill     27081 non-null object
# date          61551 non-null object
# dtypes: object(15)
# memory usage: 7.5+ MB

# %%
df_weather.ix[0,'date']+' '+df_weather.ix[0,'Time']
# Out:
# '2015-09-13 12:53 AM'

# %%
times = []
for row in xrange(25):
    dt = df_weather.ix[row,'date']+' '+df_weather.ix[row,'Time']
    times.append(dt)
pd.to_datetime(times)
# Out:
# DatetimeIndex(['2015-09-13 00:53:00', '2015-09-13 01:53:00',
#                '2015-09-13 02:53:00', '2015-09-13 03:37:00',
#                '2015-09-13 03:53:00', '2015-09-13 04:53:00',
#                '2015-09-13 05:53:00', '2015-09-13 06:53:00',
#                '2015-09-13 07:53:00', '2015-09-13 08:53:00',
#                '2015-09-13 09:00:00', '2015-09-13 09:53:00',
#                '2015-09-13 10:25:00', '2015-09-13 10:53:00',
#                '2015-09-13 11:53:00', '2015-09-13 12:53:00',
#                '2015-09-13 13:44:00', '2015-09-13 13:53:00',
#                '2015-09-13 14:53:00', '2015-09-13 15:53:00',
#                '2015-09-13 16:53:00', '2015-09-13 17:53:00',
#                '2015-09-13 18:53:00', '2015-09-13 19:53:00',
#                '2015-09-13 20:53:00'],
#               dtype='datetime64[ns]', freq=None, tz=None)

# %%
for row in xrange(50):
    dt = df_weather.ix[row,'date']+' '+df_weather.ix[row,'Time']
    dt = datetime.datetime.strptime(dt, "%Y-%m-%d %I:%M %p")
    dt = datetime.datetime.strftime(dt, "%Y-%m-%d %I:%M %p")                                
    print type(dt)
# Out:
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>

# %%
df_temp = df_weather[['date','Time','Temp.']]

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61551 entries, 0 to 61550
# Data columns (total 3 columns):
# date     61551 non-null object
# Time     61551 non-null object
# Temp.    61551 non-null object
# dtypes: object(3)
# memory usage: 1.9+ MB

# %%
df_temp.head()
# Out:
#          date      Time    Temp.
# 0  2015-09-13  12:53 AM  66.0 °F
# 1  2015-09-13   1:53 AM  64.9 °F
# 2  2015-09-13   2:53 AM  64.0 °F
# 3  2015-09-13   3:37 AM  62.6 °F
# 4  2015-09-13   3:53 AM  62.1 °F

# %%
df_temp['dt'] =

# %%
dataframe["Year"].map(str) + dataframe["quarter"]

# %%
df['dt'] = pd.to_datetime(df.apply(lambda x: x['Date[G]'] + ' ' + x['Time[G]'], 1))

# %%
df_temp['dt'] = pd.to_datetime(df_temp.apply(lambda x: x['date'] + ' ' + x['Time'], 1))
# Out:
# C:\Users\andersrmr\Anaconda\lib\site-packages\IPython\kernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_temp.head()
# Out:
#          date      Time    Temp.                  dt
# 0  2015-09-13  12:53 AM  66.0 °F 2015-09-13 00:53:00
# 1  2015-09-13   1:53 AM  64.9 °F 2015-09-13 01:53:00
# 2  2015-09-13   2:53 AM  64.0 °F 2015-09-13 02:53:00
# 3  2015-09-13   3:37 AM  62.6 °F 2015-09-13 03:37:00
# 4  2015-09-13   3:53 AM  62.1 °F 2015-09-13 03:53:00

# %%
df_temp = df_temp.set_index('dt')

# %%
df_temp = df_temp.drop(['date','Time'], axis = 1)

# %%
df_temp.head()
# Out:
#                        Temp.
# dt
# 2015-09-13 00:53:00  66.0 °F
# 2015-09-13 01:53:00  64.9 °F
# 2015-09-13 02:53:00  64.0 °F
# 2015-09-13 03:37:00  62.6 °F
# 2015-09-13 03:53:00  62.1 °F

# %%
'54321'[:-3]
# Out:
# '54'

# %%
df_temp = df_temp.apply(lambda x: x.str[:-5])

# %%
df_temp.index
# Out:
# DatetimeIndex(['2015-09-13 00:53:00', '2015-09-13 01:53:00',
#                '2015-09-13 02:53:00', '2015-09-13 03:37:00',
#                '2015-09-13 03:53:00', '2015-09-13 04:53:00',
#                '2015-09-13 05:53:00', '2015-09-13 06:53:00',
#                '2015-09-13 07:53:00', '2015-09-13 08:53:00',
#                ...
#                '2009-06-18 14:53:00', '2009-06-18 15:53:00',
#                '2009-06-18 16:53:00', '2009-06-18 17:53:00',
#                '2009-06-18 18:53:00', '2009-06-18 19:53:00',
#                '2009-06-18 20:53:00', '2009-06-18 21:53:00',
#                '2009-06-18 22:53:00', '2009-06-18 23:53:00'],
#               dtype='datetime64[ns]', name=u'dt', length=61551, freq=None, tz=None)

# %%
df_temp['Temp.'].values
# Out:
# array(['66.0', '64.9', '64.0', ..., '64.9', '63.0', '62.1'], dtype=object)

# %%
type(df_temp['Temp.'].values)
# Out:
# numpy.ndarray

# %%
df_temp.ix[:,'Temp.'].apply(lambda x: x[:-5].replace(u"\xf1", ""))
# Out:
# dt
# 2015-09-13 00:53:00    66.0
# 2015-09-13 01:53:00    64.9
# 2015-09-13 02:53:00    64.0
# 2015-09-13 03:37:00    62.6
# 2015-09-13 03:53:00    62.1
# 2015-09-13 04:53:00    62.1
# 2015-09-13 05:53:00    62.1
# 2015-09-13 06:53:00    63.0
# 2015-09-13 07:53:00    63.0
# 2015-09-13 08:53:00    62.1
# 2015-09-13 09:00:00    62.6
# 2015-09-13 09:53:00    63.0
# 2015-09-13 10:25:00    62.6
# 2015-09-13 10:53:00    63.0
# 2015-09-13 11:53:00    64.0
# 2015-09-13 12:53:00    64.0
# 2015-09-13 13:44:00    66.2
# 2015-09-13 13:53:00    66.0
# 2015-09-13 14:53:00    66.9
# 2015-09-13 15:53:00    72.0
# 2015-09-13 16:53:00    70.0
# 2015-09-13 17:53:00    66.9
# 2015-09-13 18:53:00    63.0
# 2015-09-13 19:53:00    62.1
# 2015-09-13 20:53:00    61.0
# 2015-09-13 21:53:00    62.1
# 2015-09-13 22:53:00    62.1
# 2015-09-13 23:53:00    59.0
# 2015-09-12 00:53:00    66.9
# 2015-09-12 01:53:00    64.9
#                        ...
# 2009-06-19 21:53:00    60.1
# 2009-06-19 22:00:00    60.8
# ...

# %%
df_temp['Temp.'].values
# Out:
# array(['66.0', '64.9', '64.0', ..., '64.9', '63.0', '62.1'], dtype=object)

# %%
df_temp.index
# Out:
# DatetimeIndex(['2015-09-13 00:53:00', '2015-09-13 01:53:00',
#                '2015-09-13 02:53:00', '2015-09-13 03:37:00',
#                '2015-09-13 03:53:00', '2015-09-13 04:53:00',
#                '2015-09-13 05:53:00', '2015-09-13 06:53:00',
#                '2015-09-13 07:53:00', '2015-09-13 08:53:00',
#                ...
#                '2009-06-18 14:53:00', '2009-06-18 15:53:00',
#                '2009-06-18 16:53:00', '2009-06-18 17:53:00',
#                '2009-06-18 18:53:00', '2009-06-18 19:53:00',
#                '2009-06-18 20:53:00', '2009-06-18 21:53:00',
#                '2009-06-18 22:53:00', '2009-06-18 23:53:00'],
#               dtype='datetime64[ns]', name=u'dt', length=61551, freq=None, tz=None)

# %%
len(df_temp.values)
# Out:
# 61551

# %%
for row in xrange(len(df_temp.values)):
    print type(float(df_temp.values[row,0]))
# Out:
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# <type 'float'>
# ...

# %%
df['HD01_VD01'] = df['HD01_VD01'].\
        convert_objects(convert_numeric=True)

# %%
df_ = df_temp.convert_objects(convert_numeric=True)

# %%
df_[pd.isnull(df_['Temp.'])]
# Out:
#                      Temp.
# dt
# 2015-02-13 12:53:00    NaN
# 2014-12-23 11:53:00    NaN
# 2014-12-23 12:00:00    NaN
# 2014-12-23 12:53:00    NaN
# 2014-10-26 08:53:00    NaN
# 2014-10-17 02:07:00    NaN
# 2014-07-05 01:53:00    NaN
# 2014-01-25 13:53:00    NaN
# 2013-11-07 12:53:00    NaN
# 2013-06-13 22:53:00    NaN
# 2012-12-20 00:53:00    NaN
# 2012-12-20 01:53:00    NaN
# 2012-12-20 02:53:00    NaN
# 2012-12-20 03:53:00    NaN
# 2012-12-20 04:53:00    NaN
# 2012-12-19 21:53:00    NaN
# 2012-12-19 22:53:00    NaN
# 2012-12-19 23:53:00    NaN
# 2012-02-21 09:53:00    NaN
# 2012-02-20 12:53:00    NaN
# 2012-02-20 13:25:00    NaN
# 2012-02-20 13:47:00    NaN
# 2012-02-20 14:53:00    NaN
# 2012-02-20 15:53:00    NaN
# 2011-06-09 07:30:00    NaN
# 2011-03-16 16:53:00    NaN
# 2011-02-01 12:53:00    NaN
# 2011-01-26 00:53:00    NaN
# 2011-01-26 01:53:00    NaN
# 2011-01-26 02:53:00    NaN
# 2011-01-26 03:44:00    NaN
# 2011-01-26 03:47:00    NaN
# 2011-01-26 03:53:00    NaN
# ...

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 61551 entries, 2015-09-13 00:53:00 to 2009-06-18 23:53:00
# Data columns (total 1 columns):
# Temp.    61500 non-null float64
# dtypes: float64(1)
# memory usage: 961.7 KB

# %%
temps = []
for row in xrange(len(df_temp.values)):
    tp = float(df_temp.values[row,0])
    temps.append(tp)
temps_all = pd.Series(temps, index=df_temp.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-203-262832d7ead6> in <module>()
#       1 temps = []
#       2 for row in xrange(len(df_temp.values)):
# ----> 3     tp = float(df_temp.values[row,0])
#       4     temps.append(tp)
#       5 temps_all = pd.Series(temps, index=df_temp.index)
#
# ValueError: could not convert string to float:

# %%
df_temp = df_temp.convert_objects(convert_numeric=True)

# %%
df_temp_ = df_temp.resample('D', how='mean')

# %%
df_temp_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2279 entries, 2009-06-18 to 2015-09-13
# Freq: D
# Data columns (total 1 columns):
# Temp.    2279 non-null float64
# dtypes: float64(1)
# memory usage: 35.6 KB

# %%
df_temp_[pd.isnull(df_temp_['Temp.'])]
# Out:
# Empty DataFrame
# Columns: [Temp.]
# Index: []

# %%
df_temp_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2279 entries, 2009-06-18 to 2015-09-13
# Freq: D
# Data columns (total 1 columns):
# Temp.    2279 non-null float64
# dtypes: float64(1)
# memory usage: 35.6 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6996 entries, 0 to 10999
# Data columns (total 13 columns):
# OBJECTID            6996 non-null int64
# WOKEY               6996 non-null int64
# LOCATION            6996 non-null object
# ADDRDESC            6996 non-null object
# INITDT_dt           6996 non-null datetime64[ns]
# FLDSTARTDT_dt       6996 non-null datetime64[ns]
# FLDENDDT_dt         6996 non-null datetime64[ns]
# DURATION            6996 non-null timedelta64[ns]
# DURATION_td         6996 non-null float64
# latitude            6996 non-null float64
# longitude           6996 non-null float64
# address             6996 non-null object
# INITDT_date_only    6996 non-null object
# dtypes: datetime64[ns](3), float64(3), int64(2), object(4), timedelta64[ns](1)
# memory usage: 765.2+ KB

# %%
df = df.reset_index()

# %%
df_temp_.head(2)
# Out:
#                 Temp.
# dt
# 2009-06-18  64.884615
# 2009-06-19  60.251351

# %%
df_temp_.apply(lambda x:x+1).head(2)
# Out:
#                 Temp.
# dt
# 2009-06-18  65.884615
# 2009-06-19  61.251351

# %%
df_temp_.index
# Out:
# DatetimeIndex(['2009-06-18', '2009-06-19', '2009-06-20', '2009-06-21',
#                '2009-06-22', '2009-06-23', '2009-06-24', '2009-06-25',
#                '2009-06-26', '2009-06-27',
#                ...
#                '2015-09-04', '2015-09-05', '2015-09-06', '2015-09-07',
#                '2015-09-08', '2015-09-09', '2015-09-10', '2015-09-11',
#                '2015-09-12', '2015-09-13'],
#               dtype='datetime64[ns]', name=u'dt', length=2279, freq='D', tz=None)

# %%
df_temp_.index.values
# Out:
# array(['2009-06-17T17:00:00.000000000-0700',
#        '2009-06-18T17:00:00.000000000-0700',
#        '2009-06-19T17:00:00.000000000-0700', ...,
#        '2015-09-10T17:00:00.000000000-0700',
#        '2015-09-11T17:00:00.000000000-0700',
#        '2015-09-12T17:00:00.000000000-0700'], dtype='datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6996 entries, 0 to 6995
# Data columns (total 14 columns):
# index               6996 non-null int64
# OBJECTID            6996 non-null int64
# WOKEY               6996 non-null int64
# LOCATION            6996 non-null object
# ADDRDESC            6996 non-null object
# INITDT_dt           6996 non-null datetime64[ns]
# FLDSTARTDT_dt       6996 non-null datetime64[ns]
# FLDENDDT_dt         6996 non-null datetime64[ns]
# DURATION            6996 non-null timedelta64[ns]
# DURATION_td         6996 non-null float64
# latitude            6996 non-null float64
# longitude           6996 non-null float64
# address             6996 non-null object
# INITDT_date_only    6996 non-null object
# dtypes: datetime64[ns](3), float64(3), int64(3), object(4), timedelta64[ns](1)
# memory usage: 819.8+ KB

# %%
df['INITDT_date_only'] = pd.to_datetime(df.INITDT_date_only)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6996 entries, 0 to 6995
# Data columns (total 14 columns):
# index               6996 non-null int64
# OBJECTID            6996 non-null int64
# WOKEY               6996 non-null int64
# LOCATION            6996 non-null object
# ADDRDESC            6996 non-null object
# INITDT_dt           6996 non-null datetime64[ns]
# FLDSTARTDT_dt       6996 non-null datetime64[ns]
# FLDENDDT_dt         6996 non-null datetime64[ns]
# DURATION            6996 non-null timedelta64[ns]
# DURATION_td         6996 non-null float64
# latitude            6996 non-null float64
# longitude           6996 non-null float64
# address             6996 non-null object
# INITDT_date_only    6996 non-null datetime64[ns]
# dtypes: datetime64[ns](4), float64(3), int64(3), object(3), timedelta64[ns](1)
# memory usage: 819.8+ KB

# %%
df['INITDT_date_only'].order()
# Out:
# 6275   2010-03-11
# 6298   2010-03-15
# 3      2010-03-15
# 19     2010-03-15
# 6284   2010-03-16
# 6285   2010-03-16
# 4107   2010-03-16
# 4514   2010-03-16
# 2084   2010-03-16
# 441    2010-03-19
# 4096   2010-03-22
# 486    2010-03-22
# 6305   2010-03-22
# 6315   2010-03-22
# 24     2010-03-22
# 16     2010-03-24
# 6294   2010-03-24
# 4078   2010-03-24
# 6301   2010-03-24
# 4119   2010-03-24
# 6291   2010-03-24
# 2095   2010-03-24
# 2089   2010-03-24
# 1208   2010-03-24
# 3201   2010-03-26
# 2086   2010-03-26
# 6290   2010-03-26
# 5353   2010-03-26
# 3211   2010-03-27
# 2083   2010-03-27
#           ...
# 160    2015-08-07
# 158    2015-08-07
# 2199   2015-08-07
# 6418   2015-08-10
# 2201   2015-08-11
# 138    2015-08-11
# 2206   2015-08-12
# 2211   2015-08-12
# 144    2015-08-12
# 2212   2015-08-12
# 6429   2015-08-13
# 375    2015-08-13
# 132    2015-08-14
# 2218   2015-08-14
# 2214   2015-08-16
# 4226   2015-08-17
# 4224   2015-08-18
# 157    2015-08-18
# 4208   2015-08-19
# ...

# %%
df.head(2)
# Out:
#    index  OBJECTID  WOKEY                                           LOCATION  \
# 0      0         1   2456  Holden pl SW bt  SW Kenyon Holden             ...
# 1      1         2   2514  NE Pacific Street, one block west of Montlake ...
#
#                                             ADDRDESC           INITDT_dt  \
# 0  HOLDEN PL SW BETWEEN SW HOLDEN ST AND SW KENYO... 2010-03-29 07:00:00
# 1  MONTLAKE BLVD NE AND NE PACIFIC ST            ... 2010-03-30 07:00:00
#
#         FLDSTARTDT_dt         FLDENDDT_dt  DURATION  DURATION_td   latitude  \
# 0 2010-04-06 07:00:00 2010-04-06 07:00:00    8 days            8  47.531858
# 1 2010-04-01 07:00:00 2010-04-01 07:00:00    2 days            2  47.649014
#
#     longitude                                            address  \
# 0 -122.363186                     SW Kenyon St, Seattle, WA, USA
# 1 -122.304655  Montlake Blvd NE & NE Pacific St, Seattle, WA ...
#
#   INITDT_date_only
# 0       2010-03-29
# 1       2010-03-30

# %%
df['INITDT_date_only'] = df['INITDT_dt'].apply( lambda x: x.date())

# %%
df_both = pd.merge(df, df_temp_, how='left', left_on='INITDT_date_only', right_index=True)

# %%
df_both.head(2)
# Out:
#    index  OBJECTID  WOKEY                                           LOCATION  \
# 0      0         1   2456  Holden pl SW bt  SW Kenyon Holden             ...
# 1      1         2   2514  NE Pacific Street, one block west of Montlake ...
#
#                                             ADDRDESC           INITDT_dt  \
# 0  HOLDEN PL SW BETWEEN SW HOLDEN ST AND SW KENYO... 2010-03-29 07:00:00
# 1  MONTLAKE BLVD NE AND NE PACIFIC ST            ... 2010-03-30 07:00:00
#
#         FLDSTARTDT_dt         FLDENDDT_dt  DURATION  DURATION_td   latitude  \
# 0 2010-04-06 07:00:00 2010-04-06 07:00:00    8 days            8  47.531858
# 1 2010-04-01 07:00:00 2010-04-01 07:00:00    2 days            2  47.649014
#
#     longitude                                            address  \
# 0 -122.363186                     SW Kenyon St, Seattle, WA, USA
# 1 -122.304655  Montlake Blvd NE & NE Pacific St, Seattle, WA ...
#
#   INITDT_date_only      Temp.
# 0       2010-03-29  46.397436
# ...

# %%
df_both = df_both.set_index('index')

# %%
df_both.head(2)
# Out:
#        OBJECTID  WOKEY                                           LOCATION  \
# index
# 0             1   2456  Holden pl SW bt  SW Kenyon Holden             ...
# 1             2   2514  NE Pacific Street, one block west of Montlake ...
#
#                                                 ADDRDESC           INITDT_dt  \
# index
# 0      HOLDEN PL SW BETWEEN SW HOLDEN ST AND SW KENYO... 2010-03-29 07:00:00
# 1      MONTLAKE BLVD NE AND NE PACIFIC ST            ... 2010-03-30 07:00:00
#
#             FLDSTARTDT_dt         FLDENDDT_dt  DURATION  DURATION_td  \
# index
# 0     2010-04-06 07:00:00 2010-04-06 07:00:00    8 days            8
# 1     2010-04-01 07:00:00 2010-04-01 07:00:00    2 days            2
#
#         latitude   longitude  \
# index
# 0      47.531858 -122.363186
# 1      47.649014 -122.304655
#
#                                                  address INITDT_date_only  \
# index
# 0                         SW Kenyon St, Seattle, WA, USA       2010-03-29
# ...

# %%
df_both.tail(2)
# Out:
#        OBJECTID   WOKEY                                           LOCATION  \
# index
# 10998     10999   96785  9719 3rd Ave NW                               ...
# 10999     11000  107829  Rainier Ave S to S Massachusetts              ...
#
#                                                 ADDRDESC           INITDT_dt  \
# index
# 10998  3RD AVE NW BETWEEN NW 97TH ST AND NW 100TH ST ... 2011-12-28 08:00:00
# 10999  RAINIER AVE S BETWEEN RAINIER NB (I90 EB ON RP... 2012-03-19 07:00:00
#
#             FLDSTARTDT_dt         FLDENDDT_dt  DURATION  DURATION_td  \
# index
# 10998 2011-12-30 08:00:00 2011-12-30 08:00:00    2 days            2
# 10999 2012-03-20 07:00:00 2012-03-20 07:00:00    1 days            1
#
#         latitude   longitude                               address  \
# index
# 10998  47.701542 -122.374093   NW 100th St, Seattle, WA 98177, USA
# 10999  47.588483 -122.313814  S Massachusetts St, Seattle, WA, USA
#
#       INITDT_date_only      Temp.
# index
# ...

# %%
df_both.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6996 entries, 0 to 10999
# Data columns (total 14 columns):
# OBJECTID            6996 non-null int64
# WOKEY               6996 non-null int64
# LOCATION            6996 non-null object
# ADDRDESC            6996 non-null object
# INITDT_dt           6996 non-null datetime64[ns]
# FLDSTARTDT_dt       6996 non-null datetime64[ns]
# FLDENDDT_dt         6996 non-null datetime64[ns]
# DURATION            6996 non-null timedelta64[ns]
# DURATION_td         6996 non-null float64
# latitude            6996 non-null float64
# longitude           6996 non-null float64
# address             6996 non-null object
# INITDT_date_only    6996 non-null datetime64[ns]
# Temp.               6996 non-null float64
# dtypes: datetime64[ns](4), float64(4), int64(2), object(3), timedelta64[ns](1)
# memory usage: 819.8+ KB
